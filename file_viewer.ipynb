# %%
import pandas as pd

# Read the parquet file into a DataFrame
df = pd.read_parquet(r'C:\Users\Aditya\Downloads\code\option-mispricing-pipeline\data\features\cross_sectional.parquet')

# Print the first 5 rows to view the data
print(df.head())

# Optional: Print the column names and data types (schema)
print(df.info())
# Out:
#                           CONTRACT_D  PREVIOUS_S  OPEN_PRICE  HIGH_PRICE  \
# 0  OPTIDXBANKNIFTY26-JUN-2025CE57000      159.55      167.55      167.55
# 1  OPTIDXBANKNIFTY24-APR-2025CE41000    10756.80    10600.05    10670.00
# 2  OPTIDXBANKNIFTY24-APR-2025CE46500     5350.00     5190.00     5331.85
# 3  OPTIDXBANKNIFTY24-APR-2025PE46500       26.10       29.65       36.65
# 4  OPTIDXBANKNIFTY24-APR-2025PE48100       57.10       67.15       97.00
#
#    LOW_PRICE  CLOSE_PRIC  SETTLEMENT  NET_CHANGE  OI_NO_CON    VOLUME  ...  \
# 0      111.0      119.95      119.95       39.60     1073.0    5610.0  ...
# 1    10045.0    10113.35    10113.35      643.45      111.0     660.0  ...
# 2     4600.0     4651.00     4525.20      824.80     2041.0    3390.0  ...
# 3       23.3       30.10       30.10        4.00     7748.0  683280.0  ...
# 4       51.1       79.50       79.50       22.40      795.0  175950.0  ...
#
# ...

# %%
import pyarrow.parquet as pq



# View the file's schema
print("Schema:")
print(parquet_file.schema)

# View the file's metadata
print("\nMetadata:")
print(parquet_file.metadata)
# Out:
# Schema:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3
#       4
#       5 # View the file's schema
#       6 print("Schema:")
# ----> 7 print(parquet_file.schema)
#       8
#       9 # View the file's metadata
#      10 print("\nMetadata:")
#
# NameError: name 'parquet_file' is not defined

# %%
print(df.columns)
# Out:
# Index(['CONTRACT_D', 'PREVIOUS_S', 'OPEN_PRICE', 'HIGH_PRICE', 'LOW_PRICE',
#        'CLOSE_PRIC', 'SETTLEMENT', 'NET_CHANGE', 'OI_NO_CON', 'TRADED_QUA',
#        'TRD_NO_CON', 'UNDRLNG_ST', 'NOTIONAL_V', 'PREMIUM_TR', 'Date',
#        'source_file', 'expiry_date', 'option_type', 'strike', 'DTE',
#        'is_expiry_day', 'close', 'spot', 'moneyness', 'IV', 'ATM_IV', 'Skew',
#        'TS_Slope', 'HV_20', 'IV_HV_Spread', 'option_type_encoded', 'log_price',
#        'IV_relative', 'abs_moneyness', 'avg_OI_day', 'OI_normalized',
#        'avg_vol_day', 'Volume_normalized', 'IV_rank'],
#       dtype='str')
